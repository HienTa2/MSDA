# %% [markdown]
# ![image.png](attachment:d2a8bd38-70cf-4291-a066-a978047097fb.png)

# %% [markdown]
# EDA was done prior
#
#
# ![image.png](attachment:deebfd35-16ef-45c1-b57a-41ef15abfd33.png)

# %% [markdown]
# Use regression testing for D208 to get predictive modeling
#
# ![image.png](attachment:d783498b-97c8-49c1-871d-da6adca668d0.png)
